# %% [markdown]
# <a href="https://colab.research.google.com/github/anjali062428-cmyk/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane 2: Refresh / Content Opportunity Scoring focuses on identifying which content pages should be reviewed first for actions such as refreshing, expanding, protecting, pruning, or monitoring. I chose this lane because it connects search performance data with a practical decision: helping a reviewer prioritize limited time on the pages with the strongest evidence of opportunity or weakness. I also want to compare simple rules with machine-learning approaches to see whether the ranking can be improved.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Decide which content pages should be reviewed first for a potential refresh or improvement. Action: A content or SEO reviewer can use the ranking to prioritize pages for refresh, expansion, protection, pruning, or monitoring. Cost of a wrong recommendation: Prioritizing the wrong page can waste the review team's time and resources, while failing to prioritize a page with a real opportunity may mean losing a chance to improve its search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Number of pages:", len(df))
print("Average impressions:", round(df["impressions_90d"].mean(), 2))
print("Pages with declining trend:", (df["trend_direction"] == "down").sum())
# Out:
# Number of pages: 30000
# Average impressions: 5200.37
# Pages with declining trend: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What I can claim: I can use the observed data to identify pages that show signals of declining performance and prioritize them for review. The analysis can provide directional, decision-support recommendations based on the available search and content signals.
#
# What I can't claim: I cannot prove that refreshing a page will cause its performance to improve, and I cannot claim that the analysis predicts Google's ranking decisions. The results show observed patterns and support prioritization, not causal proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
